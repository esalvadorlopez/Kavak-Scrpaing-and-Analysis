# %%
import pandas as pd
import json
import gspread
from main import _create_dataframe

# %%
df = _create_dataframe()
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Erik López\Desktop\scrapp_kavak\clean.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Erik%20L%C3%B3pez/Desktop/scrapp_kavak/clean.ipynb#ch0000001?line=0'>1</a> df = _create_dataframe()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Erik%20L%C3%B3pez/Desktop/scrapp_kavak/clean.ipynb#ch0000001?line=1'>2</a> df.sample(5)
#
# File c:\Users\Erik López\Desktop\scrapp_kavak\venv\lib\site-packages\pandas\core\generic.py:5446, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5443 if weights is not None:
#    5444     weights = sample.preprocess_weights(self, weights, axis)
# -> 5446 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5447 result = self.take(sampled_indices, axis=axis)
#    5449 if ignore_index:
#
# File c:\Users\Erik López\Desktop\scrapp_kavak\venv\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# --> 150 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151     np.intp, copy=False
#     152 )
#
# File mtrand.pyx:909, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
df = df.iloc[:,1:]
df.sample(5)
# Out:
#                                title           km             price  \
# 720  Toyota Highlander 2010 #185861    124400 KM    Precio: $202999
# 653      Suzuki Vitara 2016 #154292     80840 KM    Precio: $290999
# 472     Volkswagen Gol 2020 #186401     27700 KM    Precio: $230999
# 31           Seat Leon 2016 #185610     81400 KM    Precio: $265999
# 750          Kia Forte 2018 #168975     79800 KM    Precio: $263999
#
#                                               features  \
# 720  {' Transmisión': 'Automática', 'Tracción': '4x...
# 653  {' Tracción': '4x2', 'Transmisión': 'Automátic...
# 472  {' Tracción': '4x2', 'Transmisión': 'Manual', ...
# 31   {' Tracción': '4x2', 'Transmisión': 'Automátic...
# 750  {' Transmisión': 'Automática', 'Tracción': '4x...
#
#                                                    url  \
# 720  https://www.kavak.com/mx/toyota-highlander-bas...
# 653  https://www.kavak.com/mx/suzuki-vitara-glx-201...
# 472  https://www.kavak.com/mx/volkswagen-gol-hb-tre...
# 31   https://www.kavak.com/mx/seat-leon-style-14t-2...
# 750  https://www.kavak.com/mx/kia-forte-lx-2018-com...
#
#                                             image_link
# 720  https://images.kavak.services/images/185861/EX...
# 653  https://images.kavak.services/images/154292/EX...
# 472  https://images.kavak.services/images/186401/EX...
# 31   https://images.kavak.services/images/185610/EX...
# 750  https://images.kavak.services/images/168975/EX...

# %%
df['features'] = df['features'].str.replace("'",'"')
df['features'] = df['features'].str.replace(" ",'')
df['features'] = df['features'].apply(lambda x: json.loads(x))

# %%
count=0
for row in df['features']:
    row.update({'key': count})
    count +=1
df['features']
# Out:
# 0      {'Transmisión': 'Manual', 'Uso': 'Particular',...
# 1      {'Combustible': 'Gasolina', 'Tracción': '4x2',...
# 2      {'Transmisión': 'Automática', 'Tracción': '4x2...
# 3      {'Tracción': '4x2', 'Transmisión': 'Automática...
# 4      {'Transmisión': 'Automática', 'Tracción': '4x2...
#                              ...
# 795    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 796    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 797    {'Tracción': '4x2', 'Transmisión': 'Automática...
# 798    {'Transmisión': 'Automática', 'Tracción': '4x2...
# 799    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# Name: features, Length: 800, dtype: object

# %%
features_list = []
for row in df['features']:
    features_list.append(row)
df2 = pd.DataFrame(features_list)
df2
# Out:
#     Transmisión         Uso Tracción Combustible Litros ConsumodeGasolina  \
# 0        Manual  Particular      4x2    Gasolina    1,8               8,1
# 1    Automática  Particular      4x2    Gasolina    2,5                 8
# 2    Automática         NaN      4x2         NaN    NaN               NaN
# 3    Automática         NaN      4x2         NaN    NaN               NaN
# 4    Automática         NaN      4x2         NaN    NaN               NaN
# ..          ...         ...      ...         ...    ...               ...
# 795      Manual         NaN      4x2         NaN    NaN               4.9
# 796      Manual         NaN      4x2         NaN    NaN                 6
# 797  Automática         NaN      4x2         NaN    NaN               NaN
# 798  Automática         NaN      4x2         NaN    2,5               7,7
# 799      Manual         NaN      4x2         NaN    NaN               4,6
#
#     StockID  key
# 0     47639    0
# 1     30830    1
# 2    191988    2
# 3    191577    3
# 4    190528    4
# ..      ...  ...
# 795  131110  795
# 796  127887  796
# 797  120252  797
# 798  116221  798
# 799  111246  799
#
# [800 rows x 8 columns]

# %%
df['key'] = df.index
df.head()
# Out:
#                             title           km             price  \
# 0        Honda Civic 2015 #47639     89681 KM    Precio: $230999
# 1     Nissan X Trail 2015 #30830    101777 KM    Precio: $256999
# 2      Nissan Versa 2019 #191988     29777 KM    Precio: $238999
# 3      Nissan Versa 2015 #191577     81200 KM    Precio: $174999
# 4  Volkswagen Vento 2017 #190528     72535 KM    Precio: $206999
#
#                                             features  \
# 0  {'Transmisión': 'Manual', 'Uso': 'Particular',...
# 1  {'Combustible': 'Gasolina', 'Tracción': '4x2',...
# 2  {'Transmisión': 'Automática', 'Tracción': '4x2...
# 3  {'Tracción': '4x2', 'Transmisión': 'Automática...
# 4  {'Transmisión': 'Automática', 'Tracción': '4x2...
#
#                                                  url  \
# 0  https://www.kavak.com/mx/honda-civic-lx-2015-c...
# 1  https://www.kavak.com/mx/nissan-x-trail-exclus...
# 2  https://www.kavak.com/mx/nissan-versa-sense-20...
# 3  https://www.kavak.com/mx/nissan-versa-sense-20...
# 4  https://www.kavak.com/mx/volkswagen-vento-comf...
#
#                                           image_link  key
# 0  https://images.kavak.services/images/47639/civ...    0
# 1  https://images.kavak.services/images/30830/nis...    1
# 2  https://images.kavak.services/images/191988/EX...    2
# 3  https://images.kavak.services/images/191577/EX...    3
# 4  https://images.kavak.services/images/190528/EX...    4

# %%
df_final = df.merge(df2, on='key',how='left')

# %%
df_final.sample(5)
# Out:
#                               title           km             price  \
# 275           Kia Rio 2017 #152465    109688 KM    Precio: $225999
# 427    Renault Captur 2018 #145775     78300 KM    Precio: $256999
# 104    Chevrolet Trax 2013 #176397     63300 KM    Precio: $202999
# 729  Volkswagen Vento 2019 #178707     24830 KM    Precio: $229999
# 449  Volkswagen Vento 2017 #189156     30000 KM    Precio: $203999
#
#                                               features  \
# 275  {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 427  {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 104  {'Transmisión': 'Manual', 'Tracción': '4x2', '...
# 729  {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 449  {'Transmisión': 'Manual', 'Tracción': '4x2', '...
#
#                                                    url  \
# 275  https://www.kavak.com/mx/kia-rio-hb-ex-2017-co...
# 427  https://www.kavak.com/mx/renault-captur-intens...
# 104  https://www.kavak.com/mx/chevrolet-trax-ls-201...
# 729  https://www.kavak.com/mx/volkswagen-vento-comf...
# 449  https://www.kavak.com/mx/volkswagen-vento-star...
#
#                                             image_link  key Transmisión  Uso  \
# 275  https://images.kavak.services/images/152465/EX...  275      Manual  NaN
# 427  https://images.kavak.services/images/145775/EX...  427      Manual  NaN
# 104  https://images.kavak.services/images/176397/EX...  104      Manual  NaN
# 729  https://images.kavak.services/images/178707/EX...  729      Manual  NaN
# 449  https://images.kavak.services/images/189156/EX...  449      Manual  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID
# 275      4x2         NaN    NaN                 6  152465
# 427      4x2         NaN    NaN               6.5  145775
# 104      4x2         NaN    NaN               NaN  176397
# 729      4x2         NaN    NaN               NaN  178707
# 449      4x2         NaN    NaN               NaN  189156

# %%
df_final.drop(columns = ['key','features'], inplace=True)

# %%
df_final.sample(5)
# Out:
#                                  title           km             price  \
# 77      Volkswagen Vento 2018 #179861     93200 KM    Precio: $214999
# 572         Toyota Prius 2014 #173323    125684 KM    Precio: $226999
# 629  Volkswagen Jetta A6 2016 #159612     99311 KM    Precio: $261999
# 7         Nissan X Trail 2015 #189568     60350 KM    Precio: $278999
# 730      Chevrolet Spark 2019 #177451     58076 KM    Precio: $191999
#
#                                                    url  \
# 77   https://www.kavak.com/mx/volkswagen-vento-high...
# 572  https://www.kavak.com/mx/toyota-prius-hatch-ba...
# 629  https://www.kavak.com/mx/volkswagen-jetta-a6-s...
# 7    https://www.kavak.com/mx/nissan-x-trail-sense-...
# 730  https://www.kavak.com/mx/chevrolet-spark-hatch...
#
#                                             image_link Transmisión  Uso  \
# 77   https://images.kavak.services/images/179861/EX...      Manual  NaN
# 572  https://images.kavak.services/images/173323/EX...  Automática  NaN
# 629  https://images.kavak.services/images/159612/EX...  Automática  NaN
# 7    https://images.kavak.services/images/189568/EX...  Automática  NaN
# 730  https://images.kavak.services/images/177451/EX...      Manual  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID
# 77       4x2         NaN    NaN               NaN  179861
# 572      4x2         NaN    NaN               NaN  173323
# 629      4x2         NaN    NaN               8.1  159612
# 7        4x2         NaN    NaN               NaN  189568
# 730      4x2         NaN    NaN               NaN  177451

# %%
df_final['title'] = df_final['title'].str.replace(r' #[0-9]+.*$','',regex=True)
df_final['modelo'] = df_final['title'].str.extract(r'(\s\d+$)')
df_final['title'] = df_final['title'].str.replace(r'\s\d+$','',regex=True)
df_final['brand'] = df_final['title'].str.extract(r'(^[A-Z-a-z]+) .*')

# %%
df_final['km'] = df_final['km'].str.replace(r'\D','',regex=True)
df_final['price'] = df_final['price'].str.replace(r'\D','',regex=True)
# if 'Litros' in df_final:
#     df_final['Litros'] = df_final['Litros'].str.replace(',','.')
# if 'ConsumodeGasolina' in df_final:
#     df_final['ConsumodeGasolina'] = df_final['ConsumodeGasolina'].str.replace(',','.')
# if 'NumerodeVelocidades' in df_final:
#     df_final['NumerodeVelocidades'] = df_final['NumerodeVelocidades'].str.replace(r'\D','',regex=True)

# %%
df_final.sample(5)
# Out:
#                    title      km   price  \
# 777           Honda CR-V   68000  258999
# 736         Toyota Yaris  110586  240999
# 649           Honda City   98572  193999
# 398         Nissan Versa   69500  256999
# 754  Volkswagen Jetta A6   70500  256999
#
#                                                    url  \
# 777  https://www.kavak.com/mx/honda-cr-v-ex-2013-co...
# 736  https://www.kavak.com/mx/toyota-yaris-r-xle-20...
# 649  https://www.kavak.com/mx/honda-city-ex-2014-co...
# 398  https://www.kavak.com/mx/nissan-versa-exclusiv...
# 754  https://www.kavak.com/mx/volkswagen-jetta-a6-2...
#
#                                             image_link Transmisión  Uso  \
# 777  https://images.kavak.services/images/152726/EX...  Automática  NaN
# 736  https://images.kavak.services/images/174808/EX...  Automática  NaN
# 649  https://images.kavak.services/images/156097/EX...  Automática  NaN
# 398  https://images.kavak.services/images/173312/EX...  Automática  NaN
# 754  https://images.kavak.services/images/166323/EX...      Manual  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID modelo       brand
# 777      4x2         NaN    NaN              10.4  152726   2013       Honda
# 736      4x2         NaN    NaN               NaN  174808   2016      Toyota
# 649      4x2         NaN    NaN               NaN  156097   2014       Honda
# 398      4x2         NaN    NaN               NaN  173312   2018      Nissan
# 754      4x2         NaN    NaN               6.6  166323   2018  Volkswagen

# %%
df_final = df_final[['StockID','title','brand','modelo','Transmisión','km','price','url','image_link']]

# %%
df_final.sample(5)
# Out:
#     StockID             title       brand modelo Transmisión      km   price  \
# 306  146875       Suzuki Ciaz      Suzuki   2017      Manual  101500  214999
# 649  156097        Honda City       Honda   2014  Automática   98572  193999
# 730  177451   Chevrolet Spark   Chevrolet   2019      Manual   58076  191999
# 429  145093    Renault Duster     Renault   2017  Automática   61600  242999
# 598  165496  Volkswagen Vento  Volkswagen   2019  Automática   37552  263999
#
#                                                    url  \
# 306  https://www.kavak.com/mx/suzuki-ciaz-glx-2017-...
# 649  https://www.kavak.com/mx/honda-city-ex-2014-co...
# 730  https://www.kavak.com/mx/chevrolet-spark-hatch...
# 429  https://www.kavak.com/mx/renault-duster-dynami...
# 598  https://www.kavak.com/mx/volkswagen-vento-high...
#
#                                             image_link
# 306  https://images.kavak.services/images/146875/EX...
# 649  https://images.kavak.services/images/156097/EX...
# 730  https://images.kavak.services/images/177451/EX...
# 429  https://images.kavak.services/images/145093/EX...
# 598  https://images.kavak.services/images/165496/EX...

# %%
df_final = df_final.fillna('')
df_final = df_final.drop_duplicates()

# %%
df_final = df_final.rename(columns={
    'StockID' : 'Stock Id',
    'title' : 'Automovil',
    'brand' : 'Marca',
    'modelo' : 'Modelo (Año)',
    'km' : 'Kilometraje',
    'price' : 'Precio',
    'url' : 'URL',
    'image_link' : 'URL de la Imagen'

})
