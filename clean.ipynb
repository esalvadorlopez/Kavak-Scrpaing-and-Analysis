# %%
import pandas as pd
import json
import gspread

# %%
df = pd.read_csv('raw_dataset.csv',delimiter=';')
df.sample(5)
# Out:
#                                   title          km             price  \
# 3036  Volkswagen Jetta A7 2019 #176811    64834 KM    Precio: $418999
# 6681           Seat Arona 2020 #186852    39300 KM    Precio: $378999
# 210          Nissan March 2020 #175472     8500 KM    Precio: $241999
# 3528       Chevrolet Trax 2015 #185446    71273 KM    Precio: $245999
# 2203        Mini Cooper S 2018 #180275    65880 KM    Precio: $399999
#
#                                                features  \
# 3036  {' Tracción': '4x2', 'Transmisión': 'Automátic...
# 6681  {' Transmisión': 'Automática', 'Tracción': '4x...
# 210   {' Transmisión': 'Manual', 'Tracción': '4x2', ...
# 3528  {' Tracción': '4x2', 'Transmisión': 'Automátic...
# 2203  {' Tracción': '4x2', 'Transmisión': 'Automátic...
#
#                    car_location          car_city  \
# 3036                Kavak Lerma  Ciudad de México
# 6681  Kavak Midtown Guadalajara       Guadalajara
# 210           Kavak Punto Valle         Monterrey
# 3528           Online Querétaro         Querétaro
# 2203                Online CDMX  Ciudad de México
#
#                                                     url  \
# 3036  https://www.kavak.com/mx/volkswagen-jetta-a7-h...
# 6681  https://www.kavak.com/mx/seat-arona-xcellence-...
# 210   https://www.kavak.com/mx/nissan-march-hatch-ba...
# 3528  https://www.kavak.com/mx/chevrolet-trax-ltz-18...
# 2203  https://www.kavak.com/mx/mini-cooper-s-s-chili...
#
#                                              image_link
# 3036  https://images.kavak.services/images/176811/EX...
# 6681  https://images.kavak.services/images/186852/EX...
# 210   https://images.kavak.services/images/175472/EX...
# 3528  https://images.kavak.services/images/185446/EX...
# 2203  https://images.kavak.services/images/180275/EX...

# %%
df['features'] = df['features'].str.replace("'",'"')
df['features'] = df['features'].str.replace(" ",'')
df['features'] = df['features'].apply(lambda x: json.loads(x))

# %%
count=0
for row in df['features']:
    row.update({'key': count})
    count +=1
df['features']
# Out:
# 0       {'Combustible': 'Gasolina', 'VidriosDelanteros...
# 1       {'Combustible': 'Gasolina', 'Transmisión': 'Au...
# 2       {'Transmisión': 'Automática', 'Combustible': '...
# 3       {'Transmisión': 'Automática', 'Combustible': '...
# 4       {'Combustible': 'Gasolina', 'Transmisión': 'Au...
#                               ...
# 7810    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 7811    {'Tracción': '4x4', 'Transmisión': 'Automática...
# 7812    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 7813    {'Tracción': '4x2', 'Transmisión': 'Automática...
# 7814    {'Tracción': '4x2', 'Transmisión': 'Automática...
# Name: features, Length: 7815, dtype: object

# %%
features_list = []
for row in df['features']:
    features_list.append(row)
df2 = pd.DataFrame(features_list)
df2
# Out:
#      Combustible VidriosDelanterosfuncionamiento Transmisión         Uso  \
# 0       Gasolina                      Eléctricos  Automática  Particular
# 1       Gasolina                             NaN  Automática  Particular
# 2        Híbrido                             NaN  Automática  Particular
# 3       Gasolina                             NaN  Automática  Particular
# 4       Gasolina                             NaN  Automática  Particular
# ...          ...                             ...         ...         ...
# 7810         NaN                             NaN      Manual         NaN
# 7811         NaN                             NaN  Automática         NaN
# 7812         NaN                             NaN      Manual         NaN
# 7813         NaN                             NaN  Automática         NaN
# 7814         NaN                             NaN  Automática         NaN
#
#      Tracción StockID   key Litros ConsumodeGasolina CaballosdeFuerza Turbo  \
# 0         4x4   47869     0    NaN               NaN              NaN   NaN
# 1         4x2   41530     1    2,4               7,1              NaN   NaN
# 2         4x2   39442     2    3,5               5,9              NaN   NaN
# 3         4x2   37565     3    2,5               6,6              NaN   NaN
# 4         4x2   36161     4    3,5              10,9              NaN   NaN
# ...       ...     ...   ...    ...               ...              ...   ...
# 7810      4x2  157397  7810    NaN               6.5              NaN   NaN
# 7811      4x4  157395  7811    NaN               9.8              NaN   NaN
# 7812      4x2  157392  7812    NaN               6.4              NaN   NaN
# 7813      4x2  157388  7813    NaN               6.6              NaN   NaN
# 7814      4x2  157384  7814    NaN               NaN              NaN   NaN
#
#      NumerodeVelocidades
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 7810                 NaN
# 7811                 NaN
# 7812                 NaN
# 7813                 NaN
# 7814                 NaN
#
# [7815 rows x 12 columns]

# %%
df2[df2['Litros'].isna() == True]
# Out:
#      Combustible VidriosDelanterosfuncionamiento Transmisión         Uso  \
# 0       Gasolina                      Eléctricos  Automática  Particular
# 9            NaN                             NaN  Automática         NaN
# 10           NaN                             NaN  Automática         NaN
# 11           NaN                             NaN  Automática         NaN
# 12           NaN                             NaN      Manual         NaN
# ...          ...                             ...         ...         ...
# 7810         NaN                             NaN      Manual         NaN
# 7811         NaN                             NaN  Automática         NaN
# 7812         NaN                             NaN      Manual         NaN
# 7813         NaN                             NaN  Automática         NaN
# 7814         NaN                             NaN  Automática         NaN
#
#      Tracción StockID   key Litros ConsumodeGasolina CaballosdeFuerza Turbo  \
# 0         4x4   47869     0    NaN               NaN              NaN   NaN
# 9         4x2  191551     9    NaN               NaN              NaN   NaN
# 10        4x2  190515    10    NaN               NaN              NaN   NaN
# 11        4x2  190402    11    NaN               NaN              NaN   NaN
# 12        4x2  190278    12    NaN               NaN              NaN   NaN
# ...       ...     ...   ...    ...               ...              ...   ...
# 7810      4x2  157397  7810    NaN               6.5              NaN   NaN
# 7811      4x4  157395  7811    NaN               9.8              NaN   NaN
# 7812      4x2  157392  7812    NaN               6.4              NaN   NaN
# 7813      4x2  157388  7813    NaN               6.6              NaN   NaN
# 7814      4x2  157384  7814    NaN               NaN              NaN   NaN
#
#      NumerodeVelocidades
# 0                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# ...                  ...
# 7810                 NaN
# 7811                 NaN
# 7812                 NaN
# 7813                 NaN
# 7814                 NaN
#
# [7775 rows x 12 columns]

# %%
df['key'] = df.index
df.head()
# Out:
#                         title           km             price  \
# 0  Jeep Wrangler 2017 #47869     60000 KM    Precio: $707999
# 1   Honda Accord 2015 #41530    105360 KM    Precio: $241999
# 2   Infiniti Q50 2017 #39442     83440 KM    Precio: $396999
# 3   Toyota Camry 2015 #37565     71350 KM    Precio: $245999
# 4      Ford Edge 2016 #36161    106640 KM    Precio: $354999
#
#                                             features       car_location  \
# 0  {'Combustible': 'Gasolina', 'VidriosDelanteros...  Kavak Punto Valle
# 1  {'Combustible': 'Gasolina', 'Transmisión': 'Au...  Kavak Punto Valle
# 2  {'Transmisión': 'Automática', 'Combustible': '...  Kavak Punto Valle
# 3  {'Transmisión': 'Automática', 'Combustible': '...  Kavak Punto Valle
# 4  {'Combustible': 'Gasolina', 'Transmisión': 'Au...  Kavak Punto Valle
#
#     car_city                                                url  \
# 0  Monterrey  https://www.kavak.com/mx/jeep-wrangler-unlimit...
# 1  Monterrey  https://www.kavak.com/mx/honda-accord-exl-2015...
# 2  Monterrey  https://www.kavak.com/mx/infiniti-q50-hibrido-...
# 3  Monterrey  https://www.kavak.com/mx/toyota-camry-xle-2015...
# 4  Monterrey  https://www.kavak.com/mx/ford-edge-sel-plus-20...
#
#                                           image_link  key
# 0  https://images.kavak.services/images/47869/wra...    0
# 1  https://images.kavak.services/images/41530/hon...    1
# 2  https://images.kavak.services/images/39442/inf...    2
# 3  https://images.kavak.services/images/37565/toy...    3
# 4  https://images.kavak.services/images/36161/for...    4

# %%
df_final = df.merge(df2, on='key',how='left')

# %%
df_final.sample(5)
# Out:
#                               title           km             price  \
# 6833   Chevrolet Trax 2018 #162421     84330 KM    Precio: $291999
# 2313  Hyundai Elantra 2016 #186376     64000 KM    Precio: $223999
# 4863    Mazda Mazda 3 2015 #170314    132400 KM    Precio: $228999
# 3680    Mini Cooper S 2017 #174772     88250 KM    Precio: $398999
# 4892    Mazda Mazda 3 2016 #170132    104850 KM    Precio: $234999
#
#                                                features         car_location  \
# 6833  {'Tracción': '4x2', 'Transmisión': 'Automática...     Online Querétaro
# 2313  {'Tracción': '4x2', 'Transmisión': 'Automática...          Online CDMX
# 4863  {'Transmisión': 'Manual', 'Tracción': '4x2', '...          Kavak Lerma
# 3680  {'Tracción': '4x2', 'Transmisión': 'Manual', '...        Online Puebla
# 4892  {'Transmisión': 'Manual', 'Tracción': '4x2', '...  Kavak Plaza Fortuna
#
#               car_city                                                url  \
# 6833         Querétaro  https://www.kavak.com/mx/chevrolet-trax-lt-201...
# 2313  Ciudad de México  https://www.kavak.com/mx/hyundai-elantra-gls-p...
# 4863  Ciudad de México  https://www.kavak.com/mx/mazda-mazda-3-i-touri...
# 3680            Puebla  https://www.kavak.com/mx/mini-cooper-s-s-chili...
# 4892  Ciudad de México  https://www.kavak.com/mx/mazda-mazda-3-hb-i-to...
#
#                                              image_link   key Combustible  \
# 6833  https://images.kavak.services/images/162421/EX...  6833         NaN
# 2313  https://images.kavak.services/images/186376/EX...  2313         NaN
# 4863  https://images.kavak.services/images/170314/EX...  4863         NaN
# 3680  https://images.kavak.services/images/174772/EX...  3680         NaN
# 4892  https://images.kavak.services/images/170132/EX...  4892         NaN
#
#      VidriosDelanterosfuncionamiento Transmisión  Uso Tracción StockID Litros  \
# 6833                             NaN  Automática  NaN      4x2  162421    NaN
# 2313                             NaN  Automática  NaN      4x2  186376    NaN
# 4863                             NaN      Manual  NaN      4x2  170314    NaN
# 3680                             NaN      Manual  NaN      4x2  174772    NaN
# 4892                             NaN      Manual  NaN      4x2  170132    NaN
#
#      ConsumodeGasolina CaballosdeFuerza Turbo NumerodeVelocidades
# 6833               6.7              NaN   NaN                 NaN
# 2313               NaN              NaN   NaN                 NaN
# 4863               NaN              NaN   NaN                 NaN
# 3680               NaN              NaN   NaN                 NaN
# 4892               NaN              NaN   NaN                 NaN

# %%
df_final.drop(columns = ['key','features'], inplace=True)

# %%
df_final.sample(5)
# Out:
#                              title          km             price  \
# 2047         Audi A4 2017 #181412    88250 KM    Precio: $432999
# 1320  Chevrolet Beat 2019 #185352    55270 KM    Precio: $186999
# 3282   Nissan Sentra 2018 #176102    66316 KM    Precio: $264999
# 1144   Infiniti QX60 2017 #190737    68115 KM    Precio: $552999
# 6678   Nissan Sentra 2018 #163090    89200 KM    Precio: $263999
#
#                 car_location          car_city  \
# 2047             Kavak Lerma  Ciudad de México
# 1320           Online Puebla            Puebla
# 3282             Online CDMX  Ciudad de México
# 1144  Kavak Forum Cuernavaca        Cuernavaca
# 6678         Kavak Punto Sur       Guadalajara
#
#                                                     url  \
# 2047  https://www.kavak.com/mx/audi-a4-s-line-2017-c...
# 1320  https://www.kavak.com/mx/chevrolet-beat-ls-201...
# 3282  https://www.kavak.com/mx/nissan-sentra-advance...
# 1144  https://www.kavak.com/mx/infiniti-qx60-qx60-pe...
# 6678  https://www.kavak.com/mx/nissan-sentra-advance...
#
#                                              image_link Combustible  \
# 2047  https://images.kavak.services/images/181412/EX...         NaN
# 1320  https://images.kavak.services/images/185352/EX...         NaN
# 3282  https://images.kavak.services/images/176102/EX...         NaN
# 1144  https://images.kavak.services/images/190737/EX...         NaN
# 6678  https://images.kavak.services/images/163090/EX...         NaN
#
#      VidriosDelanterosfuncionamiento Transmisión  Uso Tracción StockID Litros  \
# 2047                             NaN  Automática  NaN      4x2  181412    NaN
# 1320                             NaN      Manual  NaN      4x2  185352    NaN
# 3282                             NaN      Manual  NaN      4x2  176102    NaN
# 1144                             NaN  Automática  NaN      4x4  190737    NaN
# 6678                             NaN  Automática  NaN      4x2  163090    NaN
#
#      ConsumodeGasolina CaballosdeFuerza Turbo NumerodeVelocidades
# 2047               NaN              NaN   NaN                 NaN
# 1320               NaN              NaN   NaN                 NaN
# 3282               NaN              NaN   NaN                 NaN
# 1144               NaN              NaN   NaN                 NaN
# 6678               5.2              NaN   NaN                 NaN

# %%
df_final['title'] = df_final['title'].str.replace(r' #[0-9]+.*$','',regex=True)
df_final['modelo'] = df_final['title'].str.extract(r'(\s\d+$)')
df_final['title'] = df_final['title'].str.replace(r'\s\d+$','',regex=True)
df_final['brand'] = df_final['title'].str.extract(r'(^[A-Z-a-z]+) .*')
df_final['car_location'] = df_final['car_location'].str.replace(r'^\s|\s$','',regex=True)
df_final['car_city'] = df_final['car_city'].str.replace(r'^\s|\s$','',regex=True)

# %%
df_final['km'] = df_final['km'].str.replace(r'\D','',regex=True)
df_final['price'] = df_final['price'].str.replace(r'\D','',regex=True)
# if 'Litros' in df_final:
#     df_final['Litros'] = df_final['Litros'].str.replace(',','.')
# if 'ConsumodeGasolina' in df_final:
#     df_final['ConsumodeGasolina'] = df_final['ConsumodeGasolina'].str.replace(',','.')
# if 'NumerodeVelocidades' in df_final:
#     df_final['NumerodeVelocidades'] = df_final['NumerodeVelocidades'].str.replace(r'\D','',regex=True)

# %%
df_final.sample(5)
# Out:
#                     title     km   price         car_location  \
# 4371       Nissan X Trail  59820  368999        Online Puebla
# 5           Infiniti QX60  87997  395999    Kavak Punto Valle
# 5871  Volkswagen Jetta A7  60661  342999          Online CDMX
# 6269        Mazda Mazda 3  63500  314999          Online CDMX
# 5118           Honda Hr-V  97554  285999  Kavak Artz Pedregal
#
#               car_city                                                url  \
# 4371            Puebla  https://www.kavak.com/mx/nissan-x-trail-sense-...
# 5            Monterrey  https://www.kavak.com/mx/infiniti-qx60-qx60-pe...
# 5871  Ciudad de México  https://www.kavak.com/mx/volkswagen-jetta-a7-c...
# 6269  Ciudad de México  https://www.kavak.com/mx/mazda-mazda-3-s-grand...
# 5118  Ciudad de México  https://www.kavak.com/mx/honda-hr-v-uniq-2016-...
#
#                                              image_link Combustible  \
# 4371  https://images.kavak.services/images/172102/EX...         NaN
# 5     https://images.kavak.services/images/35307/inf...    Gasolina
# 5871  https://images.kavak.services/images/166304/EX...         NaN
# 6269  https://images.kavak.services/images/164912/EX...         NaN
# 5118  https://images.kavak.services/images/169201/EX...         NaN
#
#      VidriosDelanterosfuncionamiento Transmisión         Uso Tracción StockID  \
# 4371                             NaN  Automática         NaN      4x2  172102
# 5                                NaN  Automática  Particular      4x4   35307
# 5871                             NaN      Manual         NaN      4x2  166304
# 6269                             NaN  Automática         NaN      4x2  164912
# 5118                             NaN      Manual         NaN      4x2  169201
#
#      Litros ConsumodeGasolina CaballosdeFuerza Turbo NumerodeVelocidades  \
# 4371    NaN               NaN              NaN   NaN                 NaN
# 5       3,5               8,8              NaN   NaN                 NaN
# 5871    NaN               5.1              NaN   NaN                 NaN
# 6269    NaN                 7              NaN   NaN                 NaN
# 5118    NaN               NaN              NaN   NaN                 NaN
#
#      modelo       brand
# 4371   2018      Nissan
# 5      2016    Infiniti
# 5871   2019  Volkswagen
# 6269   2018       Mazda
# 5118   2016       Honda

# %%
df_final = df_final[['StockID','title','brand','modelo','Transmisión','car_city','car_location','km','price','url','image_link']]

# %%
df_final.sample(5)
# Out:
#      StockID            title      brand modelo Transmisión          car_city  \
# 5588  167451  Chevrolet Spark  Chevrolet   2019  Automática       Guadalajara
# 7556  158848  Audi Q3 Quattro       Audi   2014  Automática  Ciudad de México
# 2149  184288  Chevrolet Sonic  Chevrolet   2017      Manual  Ciudad de México
# 1731  186003       Mazda Cx-3      Mazda   2018  Automática  Ciudad de México
# 3766  174415        Kia Forte        Kia   2018      Manual         Querétaro
#
#                    car_location     km   price  \
# 5588  Kavak Midtown Guadalajara  51600  233999
# 7556        Kavak Artz Pedregal  89012  340999
# 2149        Kavak Plaza Fortuna  55304  205999
# 1731                Online CDMX  59600  353999
# 3766   Kavak Puerta la Victoria  95309  285999
#
#                                                     url  \
# 5588  https://www.kavak.com/mx/chevrolet-spark-hatch...
# 7556  https://www.kavak.com/mx/audi-q3-quattro-elite...
# 2149  https://www.kavak.com/mx/chevrolet-sonic-lt-ca...
# 1731  https://www.kavak.com/mx/mazda-cx-3-i-sport-20...
# 3766  https://www.kavak.com/mx/kia-forte-sx-2018-com...
#
#                                              image_link
# 5588  https://images.kavak.services/images/167451/EX...
# 7556  https://images.kavak.services/images/158848/EX...
# 2149  https://images.kavak.services/images/184288/EX...
# 1731  https://images.kavak.services/images/186003/EX...
# 3766  https://images.kavak.services/images/174415/EX...

# %%
df_final = df_final.fillna('')
df_final = df_final.drop_duplicates()

# %%
df_final = df_final.rename(columns={
    'StockID' : 'Stock Id',
    'title' : 'Automovil',
    'brand' : 'Marca',
    'modelo' : 'Modelo (Año)',
    'car_location':'Locación',
    'car_city': 'Ciudad',
    'km' : 'Kilometraje',
    'price' : 'Precio',
    'url' : 'URL',
    'image_link' : 'URL de la Imagen'

})

# %%
df_final.drop(df_final[df_final.Ciudad == 'None'].index, inplace=True)

# %%
df_final
# Out:
#      Stock Id         Automovil      Marca Modelo (Año) Transmisión  \
# 0       47869     Jeep Wrangler       Jeep         2017  Automática
# 1       41530      Honda Accord      Honda         2015  Automática
# 2       39442      Infiniti Q50   Infiniti         2017  Automática
# 3       37565      Toyota Camry     Toyota         2015  Automática
# 4       36161         Ford Edge       Ford         2016  Automática
# ...       ...               ...        ...          ...         ...
# 7808   157406    Chevrolet Aveo  Chevrolet         2020      Manual
# 7809   157399       Honda Civic      Honda         2016  Automática
# 7810   157397    Chevrolet Trax  Chevrolet         2017      Manual
# 7811   157395         Acura RDX      Acura         2017  Automática
# 7813   157388  Chevrolet Malibu  Chevrolet         2018  Automática
#
#                 Ciudad              Locación Kilometraje  Precio  \
# 0            Monterrey     Kavak Punto Valle       60000  707999
# 1            Monterrey     Kavak Punto Valle      105360  241999
# 2            Monterrey     Kavak Punto Valle       83440  396999
# 3            Monterrey     Kavak Punto Valle       71350  245999
# 4            Monterrey     Kavak Punto Valle      106640  354999
# ...                ...                   ...         ...     ...
# 7808            Puebla         Online Puebla       46780  209999
# 7809  Ciudad de México  Kavak Patio Santa Fe       79256  293999
# 7810            Puebla      Kavak Las Torres       69445  241999
# 7811  Ciudad de México        Kavak Cosmopol       76220  426999
# 7813            Puebla         Online Puebla       73070  376999
#
#                                                     URL  \
# 0     https://www.kavak.com/mx/jeep-wrangler-unlimit...
# 1     https://www.kavak.com/mx/honda-accord-exl-2015...
# 2     https://www.kavak.com/mx/infiniti-q50-hibrido-...
# 3     https://www.kavak.com/mx/toyota-camry-xle-2015...
# 4     https://www.kavak.com/mx/ford-edge-sel-plus-20...
# ...                                                 ...
# 7808  https://www.kavak.com/mx/chevrolet-aveo-ls-202...
# 7809  https://www.kavak.com/mx/honda-civic-turbo-sed...
# 7810  https://www.kavak.com/mx/chevrolet-trax-ls-cam...
# 7811  https://www.kavak.com/mx/acura-rdx-rdx-2017-co...
# 7813  https://www.kavak.com/mx/chevrolet-malibu-prem...
#
#                                        URL de la Imagen
# 0     https://images.kavak.services/images/47869/wra...
# 1     https://images.kavak.services/images/41530/hon...
# 2     https://images.kavak.services/images/39442/inf...
# 3     https://images.kavak.services/images/37565/toy...
# 4     https://images.kavak.services/images/36161/for...
# ...                                                 ...
# 7808  https://images.kavak.services/images/157406/EX...
# 7809  https://images.kavak.services/images/157399/EX...
# 7810  https://images.kavak.services/images/157397/EX...
# 7811  https://images.kavak.services/images/157395/EX...
# 7813  https://images.kavak.services/images/157388/EX...
#
# [7802 rows x 11 columns]
