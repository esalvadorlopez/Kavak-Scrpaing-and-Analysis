# %%
import pandas as pd
import json
import gspread

# %%
df = pd.read_csv('raw_dataset.csv')
df.sample(5)
# Out:
#      Unnamed: 0                           title          km             price  \
# 686         686     Mazda Mazda 3 2016 #139935    90200 KM    Precio: $235999
# 18           18  Volkswagen Vento 2018 #186982    97016 KM    Precio: $226999
# 443         443   Volkswagen Polo 2018 #191665    45820 KM    Precio: $217999
# 9             9     Renault Logan 2019 #188116    56050 KM    Precio: $202999
# 407         407    Chevrolet Aveo 2020 #164933    41700 KM    Precio: $223999
#
#                                               features  \
# 686  {' Tracción': '4x2', 'Transmisión': 'Manual', ...
# 18   {' Transmisión': 'Manual', 'Tracción': '4x2', ...
# 443  {' Transmisión': 'Manual', 'Tracción': '4x2', ...
# 9    {' Transmisión': 'Manual', 'Tracción': '4x2', ...
# 407  {' Tracción': '4x2', 'Transmisión': 'Manual', ...
#
#                      car_location  \
# 686                   Kavak Lerma
# 18   Kavak El Rosario Town Center
# 443                   Kavak Lerma
# 9    Kavak El Rosario Town Center
# 407     Kavak Antara Fashion Hall
#
#                                                    url  \
# 686  https://www.kavak.com/mx/mazda-mazda-3-i-touri...
# 18   https://www.kavak.com/mx/volkswagen-vento-soun...
# 443  https://www.kavak.com/mx/volkswagen-polo-hatch...
# 9    https://www.kavak.com/mx/renault-logan-intens-...
# 407  https://www.kavak.com/mx/chevrolet-aveo-lt-202...
#
#                                             image_link
# 686  https://images.kavak.services/images/139935/EX...
# 18   https://images.kavak.services/images/186982/EX...
# 443  https://images.kavak.services/images/191665/EX...
# 9    https://images.kavak.services/images/188116/EX...
# 407  https://images.kavak.services/images/164933/EX...

# %%
df = df.iloc[:,1:]
df.sample(5)
# Out:
#                              title          km             price  \
# 693    Mazda Mazda 3 2017 #130046    96117 KM    Precio: $255999
# 79   Chevrolet Sonic 2016 #179377    93700 KM    Precio: $162999
# 34     Mazda Mazda 3 2017 #184610    78490 KM    Precio: $228999
# 69         Acura RDX 2014 #180268    72600 KM    Precio: $296999
# 532   Toyota Corolla 2017 #181718    94692 KM    Precio: $245999
#
#                                               features  \
# 693  {' Tracción': '4x2', 'Transmisión': 'Automátic...
# 79   {' Tracción': '4x2', 'Transmisión': 'Manual', ...
# 34   {' Transmisión': 'Manual', 'Tracción': '4x2', ...
# 69   {' Tracción': '4x4', 'Transmisión': 'Automátic...
# 532  {' Tracción': '4x2', 'Transmisión': 'Automátic...
#
#                      car_location  \
# 693                   Kavak Lerma
# 79   Kavak El Rosario Town Center
# 34   Kavak El Rosario Town Center
# 69   Kavak El Rosario Town Center
# 532                   Kavak Lerma
#
#                                                    url  \
# 693  https://www.kavak.com/mx/mazda-mazda-3-i-touri...
# 79   https://www.kavak.com/mx/chevrolet-sonic-ls-li...
# 34   https://www.kavak.com/mx/mazda-mazda-3-i-2017-...
# 69   https://www.kavak.com/mx/acura-rdx-rdx-2014-co...
# 532  https://www.kavak.com/mx/toyota-corolla-base-2...
#
#                                             image_link
# 693  https://images.kavak.services/images/130046/EX...
# 79   https://images.kavak.services/images/179377/EX...
# 34   https://images.kavak.services/images/184610/EX...
# 69   https://images.kavak.services/images/180268/EX...
# 532  https://images.kavak.services/images/181718/EX...

# %%
df['features'] = df['features'].str.replace("'",'"')
df['features'] = df['features'].str.replace(" ",'')
df['features'] = df['features'].apply(lambda x: json.loads(x))

# %%
count=0
for row in df['features']:
    row.update({'key': count})
    count +=1
df['features']
# Out:
# 0      {'Transmisión': 'Manual', 'Uso': 'Particular',...
# 1      {'Transmisión': 'Automática', 'Tracción': '4x2...
# 2      {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 3      {'Transmisión': 'Automática', 'Tracción': '4x2...
# 4      {'Tracción': '4x2', 'Transmisión': 'Automática...
#                              ...
# 696    {'Tracción': '4x2', 'Transmisión': 'Automática...
# 697    {'Tracción': '4x2', 'Transmisión': 'Automática...
# 698    {'Tracción': '4x2', 'Transmisión': 'Automática...
# 699    {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 700    {'Transmisión': 'Automática', 'Tracción': '4x2...
# Name: features, Length: 701, dtype: object

# %%
features_list = []
for row in df['features']:
    features_list.append(row)
df2 = pd.DataFrame(features_list)
df2
# Out:
#     Transmisión         Uso Tracción Combustible Litros ConsumodeGasolina  \
# 0        Manual  Particular      4x2    Gasolina    1,8               8,1
# 1    Automática         NaN      4x2         NaN    NaN               NaN
# 2        Manual         NaN      4x2         NaN    NaN               NaN
# 3    Automática         NaN      4x2         NaN    NaN               NaN
# 4    Automática         NaN      4x2         NaN    NaN               NaN
# ..          ...         ...      ...         ...    ...               ...
# 696  Automática         NaN      4x2         NaN    NaN               NaN
# 697  Automática         NaN      4x2         NaN    NaN               5.6
# 698  Automática         NaN      4x2         NaN    NaN               5,3
# 699      Manual         NaN      4x2         NaN    1,5               5,1
# 700  Automática         NaN      4x2         NaN    1,6               6,4
#
#     StockID  key
# 0     47639    0
# 1    191988    1
# 2    190907    2
# 3    190108    3
# 4    189720    4
# ..      ...  ...
# 696  126291  696
# 697  126272  697
# 698  121661  698
# 699  119952  699
# 700  108922  700
#
# [701 rows x 8 columns]

# %%
df['key'] = df.index
df.head()
# Out:
#                           title          km             price  \
# 0      Honda Civic 2015 #47639    89681 KM    Precio: $230999
# 1    Nissan Versa 2019 #191988    29777 KM    Precio: $238999
# 2   Nissan Sentra 2018 #190907    55531 KM    Precio: $284999
# 3  Ford Eco Sport 2016 #190108    43300 KM    Precio: $258999
# 4      Honda City 2018 #189720    85400 KM    Precio: $275999
#
#                                             features  \
# 0  {'Transmisión': 'Manual', 'Uso': 'Particular',...
# 1  {'Transmisión': 'Automática', 'Tracción': '4x2...
# 2  {'Tracción': '4x2', 'Transmisión': 'Manual', '...
# 3  {'Transmisión': 'Automática', 'Tracción': '4x2...
# 4  {'Tracción': '4x2', 'Transmisión': 'Automática...
#
#                    car_location  \
# 0  Kavak El Rosario Town Center
# 1  Kavak El Rosario Town Center
# 2  Kavak El Rosario Town Center
# 3  Kavak El Rosario Town Center
# 4  Kavak El Rosario Town Center
#
#                                                  url  \
# 0  https://www.kavak.com/mx/honda-civic-lx-2015-c...
# 1  https://www.kavak.com/mx/nissan-versa-sense-20...
# 2  https://www.kavak.com/mx/nissan-sentra-advance...
# 3  https://www.kavak.com/mx/ford-eco-sport-trend-...
# 4  https://www.kavak.com/mx/honda-city-ex-2018-co...
#
#                                           image_link  key
# 0  https://images.kavak.services/images/47639/civ...    0
# 1  https://images.kavak.services/images/191988/EX...    1
# 2  https://images.kavak.services/images/190907/EX...    2
# 3  https://images.kavak.services/images/190108/EX...    3
# 4  https://images.kavak.services/images/189720/EX...    4

# %%
df_final = df.merge(df2, on='key',how='left')

# %%
df_final.sample(5)
# Out:
#                                  title          km             price  \
# 433         Toyota Yaris 2017 #131224    73818 KM    Precio: $218999
# 445        Nissan Sentra 2018 #190960    33000 KM    Precio: $289999
# 166       Chevrolet Trax 2019 #170225    30954 KM    Precio: $292999
# 457         Toyota Prius 2015 #187998    81700 KM    Precio: $249999
# 422  Volkswagen Jetta A6 2016 #147864    85836 KM    Precio: $210999
#
#                                               features  \
# 433  {'Tracción': '4x2', 'Transmisión': 'Automática...
# 445  {'Transmisión': 'Automática', 'Tracción': '4x2...
# 166  {'Transmisión': 'Manual', 'Tracción': '4x2', '...
# 457  {'Tracción': '4x2', 'Transmisión': 'Automática...
# 422  {'Tracción': '4x2', 'Transmisión': 'Automática...
#
#                      car_location  \
# 433     Kavak Antara Fashion Hall
# 445                   Kavak Lerma
# 166  Kavak El Rosario Town Center
# 457                   Kavak Lerma
# 422     Kavak Antara Fashion Hall
#
#                                                    url  \
# 433  https://www.kavak.com/mx/toyota-yaris-hatch-ba...
# 445  https://www.kavak.com/mx/nissan-sentra-advance...
# 166  https://www.kavak.com/mx/chevrolet-trax-ls-201...
# 457  https://www.kavak.com/mx/toyota-prius-hatch-ba...
# 422  https://www.kavak.com/mx/volkswagen-jetta-a6-2...
#
#                                             image_link  key Transmisión  Uso  \
# 433  https://images.kavak.services/images/131224/EX...  433  Automática  NaN
# 445  https://images.kavak.services/images/190960/EX...  445  Automática  NaN
# 166  https://images.kavak.services/images/170225/EX...  166      Manual  NaN
# 457  https://images.kavak.services/images/187998/EX...  457  Automática  NaN
# 422  https://images.kavak.services/images/147864/EX...  422  Automática  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID
# 433      4x2         NaN    NaN               5.3  131224
# 445      4x2         NaN    NaN               NaN  190960
# 166      4x2         NaN    NaN               NaN  170225
# 457      4x2         NaN    NaN               NaN  187998
# 422      4x2         NaN    NaN               6.8  147864

# %%
df_final.drop(columns = ['key','features'], inplace=True)

# %%
df_final.sample(5)
# Out:
#                              title          km             price  \
# 418        Kia Forte 2017 #155241    63400 KM    Precio: $208999
# 629  Chevrolet Cruze 2018 #160876    81026 KM    Precio: $247999
# 121          Kia Rio 2017 #174686    95300 KM    Precio: $231999
# 540   Renault Captur 2018 #180990    64100 KM    Precio: $258999
# 441   Renault Duster 2018 #191990    59000 KM    Precio: $266999
#
#                      car_location  \
# 418     Kavak Antara Fashion Hall
# 629                   Kavak Lerma
# 121  Kavak El Rosario Town Center
# 540                   Kavak Lerma
# 441                   Kavak Lerma
#
#                                                    url  \
# 418  https://www.kavak.com/mx/kia-forte-lx-2017-com...
# 629  https://www.kavak.com/mx/chevrolet-cruze-ls-tu...
# 121  https://www.kavak.com/mx/kia-rio-hb-ex-2017-co...
# 540  https://www.kavak.com/mx/renault-captur-intens...
# 441  https://www.kavak.com/mx/renault-duster-intens...
#
#                                             image_link Transmisión  Uso  \
# 418  https://images.kavak.services/images/155241/EX...      Manual  NaN
# 629  https://images.kavak.services/images/160876/EX...  Automática  NaN
# 121  https://images.kavak.services/images/174686/EX...      Manual  NaN
# 540  https://images.kavak.services/images/180990/EX...  Automática  NaN
# 441  https://images.kavak.services/images/191990/EX...      Manual  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID
# 418      4x2         NaN    NaN               6.4  155241
# 629      4x2         NaN    NaN               5.8  160876
# 121      4x2         NaN    NaN               NaN  174686
# 540      4x2         NaN    NaN               NaN  180990
# 441      4x2         NaN    NaN               NaN  191990

# %%
df_final['title'] = df_final['title'].str.replace(r' #[0-9]+.*$','',regex=True)
df_final['modelo'] = df_final['title'].str.extract(r'(\s\d+$)')
df_final['title'] = df_final['title'].str.replace(r'\s\d+$','',regex=True)
df_final['brand'] = df_final['title'].str.extract(r'(^[A-Z-a-z]+) .*')
df_final['car_location'] = df_final['car_location'].str.replace(r'^\s|\s$','',regex=True)

# %%
df_final['km'] = df_final['km'].str.replace(r'\D','',regex=True)
df_final['price'] = df_final['price'].str.replace(r'\D','',regex=True)
# if 'Litros' in df_final:
#     df_final['Litros'] = df_final['Litros'].str.replace(',','.')
# if 'ConsumodeGasolina' in df_final:
#     df_final['ConsumodeGasolina'] = df_final['ConsumodeGasolina'].str.replace(',','.')
# if 'NumerodeVelocidades' in df_final:
#     df_final['NumerodeVelocidades'] = df_final['NumerodeVelocidades'].str.replace(r'\D','',regex=True)

# %%
df_final.sample(5)
# Out:
#                    title      km   price               car_location  \
# 367       Chevrolet Beat   47800  193999  Kavak Antara Fashion Hall
# 605       Chevrolet Beat   37380  196999                Kavak Lerma
# 651        Mazda Mazda 2   39300  292999                Kavak Lerma
# 385  Suzuki Grand Vitara  119400  210999  Kavak Antara Fashion Hall
# 539              Kia Rio   83279  265999                Kavak Lerma
#
#                                                    url  \
# 367  https://www.kavak.com/mx/chevrolet-beat-activ-...
# 605  https://www.kavak.com/mx/chevrolet-beat-lt-201...
# 651  https://www.kavak.com/mx/mazda-mazda-2-hatch-b...
# 385  https://www.kavak.com/mx/suzuki-grand-vitara-g...
# 539  https://www.kavak.com/mx/kia-rio-ex-2018-compr...
#
#                                             image_link Transmisión  Uso  \
# 367  https://images.kavak.services/images/190040/EX...      Manual  NaN
# 605  https://images.kavak.services/images/165058/EX...      Manual  NaN
# 651  https://images.kavak.services/images/156375/EX...  Automática  NaN
# 385  https://images.kavak.services/images/178380/EX...  Automática  NaN
# 539  https://images.kavak.services/images/181079/EX...      Manual  NaN
#
#     Tracción Combustible Litros ConsumodeGasolina StockID modelo      brand
# 367      4x2         NaN    NaN               NaN  190040   2019  Chevrolet
# 605      4x2         NaN    NaN               4.8  165058   2019  Chevrolet
# 651      4x2         NaN    NaN               5.1  156375   2018      Mazda
# 385      4x2         NaN    NaN               NaN  178380   2013     Suzuki
# 539      4x2         NaN    NaN               NaN  181079   2018        Kia

# %%
df_final = df_final[['StockID','title','brand','modelo','Transmisión','car_location','km','price','url','image_link']]

# %%
df_final.sample(5)
# Out:
#     StockID            title      brand modelo Transmisión  \
# 226  161767    Nissan Sentra     Nissan   2018      Manual
# 182  167269     Toyota Yaris     Toyota   2017  Automática
# 174  169189  Chevrolet Sonic  Chevrolet   2017      Manual
# 317  142381          Audi A3       Audi   2015  Automática
# 111  175635     Nissan Versa     Nissan   2019  Automática
#
#                      car_location      km   price  \
# 226  Kavak El Rosario Town Center   69000  242999
# 182  Kavak El Rosario Town Center   81057  211999
# 174  Kavak El Rosario Town Center   41937  196999
# 317  Kavak El Rosario Town Center  120000  289999
# 111  Kavak El Rosario Town Center   34304  269999
#
#                                                    url  \
# 226  https://www.kavak.com/mx/nissan-sentra-advance...
# 182  https://www.kavak.com/mx/toyota-yaris-core-201...
# 174  https://www.kavak.com/mx/chevrolet-sonic-lt-ca...
# 317  https://www.kavak.com/mx/audi-a3-attraction-18...
# 111  https://www.kavak.com/mx/nissan-versa-exclusiv...
#
#                                             image_link
# 226  https://images.kavak.services/images/161767/EX...
# 182  https://images.kavak.services/images/167269/EX...
# 174  https://images.kavak.services/images/169189/EX...
# 317  https://images.kavak.services/images/142381/EX...
# 111  https://images.kavak.services/images/175635/EX...

# %%
df_final = df_final.fillna('')
df_final = df_final.drop_duplicates()

# %%
df_final = df_final.rename(columns={
    'StockID' : 'Stock Id',
    'title' : 'Automovil',
    'brand' : 'Marca',
    'modelo' : 'Modelo (Año)',
    'car_location':'Locación',
    'km' : 'Kilometraje',
    'price' : 'Precio',
    'url' : 'URL',
    'image_link' : 'URL de la Imagen'

})

# %%
df_final
# Out:
#     Stock Id        Automovil      Marca Modelo (Año) Transmisión  \
# 0      47639      Honda Civic      Honda         2015      Manual
# 1     191988     Nissan Versa     Nissan         2019  Automática
# 2     190907    Nissan Sentra     Nissan         2018      Manual
# 3     190108   Ford Eco Sport       Ford         2016  Automática
# 4     189720       Honda City      Honda         2018  Automática
# ..       ...              ...        ...          ...         ...
# 696   126291      Seat Toledo       Seat         2018  Automática
# 697   126272  Chevrolet Cruze  Chevrolet         2017  Automática
# 698   121661       Seat Arona       Seat         2018  Automática
# 699   119952        Ford Figo       Ford         2019      Manual
# 700   108922  Chevrolet Sonic  Chevrolet         2017  Automática
#
#                          Locación Kilometraje  Precio  \
# 0    Kavak El Rosario Town Center       89681  230999
# 1    Kavak El Rosario Town Center       29777  238999
# 2    Kavak El Rosario Town Center       55531  284999
# 3    Kavak El Rosario Town Center       43300  258999
# 4    Kavak El Rosario Town Center       85400  275999
# ..                            ...         ...     ...
# 696                   Kavak Lerma       59820  253999
# 697                   Kavak Lerma       65523  262999
# 698                   Kavak Lerma       27000  299999
# 699                   Kavak Lerma       53900  191999
# 700                   Kavak Lerma       75200  198999
#
#                                                    URL  \
# 0    https://www.kavak.com/mx/honda-civic-lx-2015-c...
# 1    https://www.kavak.com/mx/nissan-versa-sense-20...
# 2    https://www.kavak.com/mx/nissan-sentra-advance...
# 3    https://www.kavak.com/mx/ford-eco-sport-trend-...
# 4    https://www.kavak.com/mx/honda-city-ex-2018-co...
# ..                                                 ...
# 696  https://www.kavak.com/mx/seat-toledo-style-14-...
# 697  https://www.kavak.com/mx/chevrolet-cruze-lt-pr...
# 698  https://www.kavak.com/mx/seat-arona-style-2018...
# 699  https://www.kavak.com/mx/ford-figo-energy-2019...
# 700  https://www.kavak.com/mx/chevrolet-sonic-ltz-c...
#
#                                       URL de la Imagen
# 0    https://images.kavak.services/images/47639/civ...
# 1    https://images.kavak.services/images/191988/EX...
# 2    https://images.kavak.services/images/190907/EX...
# 3    https://images.kavak.services/images/190108/EX...
# 4    https://images.kavak.services/images/189720/EX...
# ..                                                 ...
# 696  https://images.kavak.services/images/126291/EX...
# 697  https://images.kavak.services/images/126272/EX...
# 698  https://images.kavak.services/images/121661/EX...
# 699  https://images.kavak.services/images/119952/EX...
# 700  https://images.kavak.services/images/108922/so...
#
# [701 rows x 10 columns]
